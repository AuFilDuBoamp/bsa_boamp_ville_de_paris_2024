# %% [markdown]
# <a href="https://www.kaggle.com/code/aufilduboamp/b-04-codedepartement?scriptVersionId=201980129" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Colonne «B_04_codeDepartement» (Initialisation)

# %% [markdown]
# # Intro

# %% [markdown]
# # Import(s) et réglages

# %%
# import
import pandas as pd
#réglages
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# # Téléchargement des annonces de la Ville de Paris sur Datagouv

# %%
df = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/8571acc8-2f51-4d7e-9d87-bd5b8ec210e5', dtype='string')

# Adresse ressources sur datagouv
# -> https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources

# %% [markdown]
# # Sélection de la colonne B_04_codeDepartement

# %%
df_B04 = df.loc[:, ['B_04_codeDepartement']].copy()

# %% [markdown]
# # Lecture des dernières lignes

# %%
df_B04.loc[df_B04.B_04_codeDepartement.notna(),:].tail()
# Out:
#     B_04_codeDepartement
# 747                   75
# 748                   75
# 749                   75
# 750                   75
# 751                   75
