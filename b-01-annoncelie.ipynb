# %% [markdown]
# <a href="https://www.kaggle.com/code/aufilduboamp/b-01-annoncelie?scriptVersionId=201979412" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Colonne «B_01_annonceLie» (Initialisation)

# %% [markdown]
# # Intro

# %% [markdown]
# # Import(s) et réglages

# %%
# import
import pandas as pd
#réglages
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# # Téléchargement des annonces de la Ville de Paris sur Datagouv

# %%
df = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/8571acc8-2f51-4d7e-9d87-bd5b8ec210e5', dtype='string')

# Adresse ressources sur datagouv
# -> https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources

# %% [markdown]
# # Sélection de la colonne B_01_annonceLie

# %%
df_B01 = df.loc[:, ['B_01_annonceLie']].copy()

# %% [markdown]
# # Lecture des dernières lignes

# %%
df_B01.loc[df_B01.B_01_annonceLie.notna(),:].tail()
# Out:
#        B_01_annonceLie
# 739  23-88639,23-90646
# 741          23-127777
# 743           23-69049
# 747          23-169290
# 749           23-87648
