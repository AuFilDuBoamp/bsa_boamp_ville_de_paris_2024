# %% [markdown]
# <a href="https://www.kaggle.com/code/aufilduboamp/col-b-35-typemarche?scriptVersionId=202020781" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Colonne « B_35_typeMarche » : Travaux, Fournitures ou Services (Initialisation)

# %% [markdown]
# # Intro

# %% [markdown]
# # Import(s) et réglages

# %%
# import
import pandas as pd
#réglages
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# # Téléchargement des annonces de la Ville de Paris sur Datagouv

# %%
df = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/8571acc8-2f51-4d7e-9d87-bd5b8ec210e5', dtype='string')

# Adresse ressources sur datagouv
# -> https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources

# %% [markdown]
# # Sélection de la colonne B_35_typeMarche

# %%
df_B35 = df.loc[:, ['B_35_typeMarche']].copy()

# %% [markdown]
# # Lecture des dernières lignes

# %%
df_B35.tail()
# Out:
#     B_35_typeMarche
# 753     FOURNITURES
# 754        SERVICES
# 755        SERVICES
# 756        SERVICES
# 757        SERVICES
