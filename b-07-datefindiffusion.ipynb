# %% [markdown]
# <a href="https://www.kaggle.com/code/aufilduboamp/b-07-datefindiffusion?scriptVersionId=202020494" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Colonne «B_07_dateFinDiffusion» (Initialisation)

# %% [markdown]
# # Intro

# %% [markdown]
# # Import(s) et réglages

# %%
# import
import pandas as pd
#réglages
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# # Téléchargement des annonces de la Ville de Paris sur Datagouv

# %%
df = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/8571acc8-2f51-4d7e-9d87-bd5b8ec210e5', dtype='string')

# Adresse ressources sur datagouv
# -> https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources

# %% [markdown]
# # Sélection de la colonne B_07_dateFinDiffusion

# %%
df_B07 = df.loc[:, ['B_07_dateFinDiffusion']].copy()

# %% [markdown]
# # Lecture des dernières lignes

# %%
df_B07.loc[df_B07.B_07_dateFinDiffusion.notna(),:].tail()
# Out:
#     B_07_dateFinDiffusion
# 753            2024-01-12
# 754            2024-03-02
# 755            2024-02-22
# 756            2024-02-05
# 757            2024-02-06
