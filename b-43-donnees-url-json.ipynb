# %% [markdown]
# <a href="https://www.kaggle.com/code/aufilduboamp/b-43-donnees-url-json?scriptVersionId=202233995" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Colonne «B_43_DONNEES_URL_JSON» (Initialisation)

# %% [markdown]
# |NAVIGATION (travaux sur les annonces BOAMP de la Ville de Paris en 2024)|
# |---|
# |[Retour à l'INDEX (kaggle)](https://www.kaggle.com/code/aufilduboamp/index-ville-de-paris-aufilduboamp)|
# |[Rubrique AuFilDuBoamp.com](https://www.aufilduboamp.com/rubrique92.html)|
# |[Dépôt GitHub](https://github.com/AuFilDuBoamp/bsa_boamp_ville_de_paris_2024/tree/main)|
# |[Dépôt DataGouv](https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources)|

# %% [markdown]
# # Import(s) et réglages

# %%
# import
import pandas as pd
#réglages
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# # Téléchargement des annonces de la Ville de Paris sur Datagouv

# %%
df = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/8571acc8-2f51-4d7e-9d87-bd5b8ec210e5', dtype='string')

# Adresse ressources sur datagouv
# -> https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources

# %% [markdown]
# # Sélection de la colonne B_43_DONNEES_URL_JSON

# %%
df_ = df.loc[:, ['B_43_DONNEES_URL_JSON']].copy()

# %% [markdown]
# # Lecture des dernières lignes

# %%
df_.loc[df_.B_43_DONNEES_URL_JSON.notna(),:].tail()
# Out:
#                                                                      B_43_DONNEES_URL_JSON
# 753   https://www.aufilduboamp.com/partages/aufilduboamp_json_p41_donnees_2024/24-243.json
# 754  https://www.aufilduboamp.com/partages/aufilduboamp_json_p41_donnees_2024/24-1437.json
# 755   https://www.aufilduboamp.com/partages/aufilduboamp_json_p41_donnees_2024/24-303.json
# 756   https://www.aufilduboamp.com/partages/aufilduboamp_json_p41_donnees_2024/24-660.json
# 757   https://www.aufilduboamp.com/partages/aufilduboamp_json_p41_donnees_2024/24-712.json
