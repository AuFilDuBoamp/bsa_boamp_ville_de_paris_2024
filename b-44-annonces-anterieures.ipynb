# %% [markdown]
# <a href="https://www.kaggle.com/code/aufilduboamp/b-44-annonces-anterieures?scriptVersionId=202233981" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Colonne «B_44_ANNONCES_ANTERIEURES» (Initialisation)

# %% [markdown]
# |NAVIGATION (travaux sur les annonces BOAMP de la Ville de Paris en 2024)|
# |---|
# |[Retour à l'INDEX (kaggle)](https://www.kaggle.com/code/aufilduboamp/index-ville-de-paris-aufilduboamp)|
# |[Rubrique AuFilDuBoamp.com](https://www.aufilduboamp.com/rubrique92.html)|
# |[Dépôt GitHub](https://github.com/AuFilDuBoamp/bsa_boamp_ville_de_paris_2024/tree/main)|
# |[Dépôt DataGouv](https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources)|

# %% [markdown]
# # Import(s) et réglages

# %%
# import
import pandas as pd
#réglages
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# # Téléchargement des annonces de la Ville de Paris sur Datagouv

# %%
df = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/8571acc8-2f51-4d7e-9d87-bd5b8ec210e5', dtype='string')

# Adresse ressources sur datagouv
# -> https://www.data.gouv.fr/fr/datasets/une-vie-de-siren-au-boamp-ville-de-paris-217500016/#/resources

# %% [markdown]
# # Sélection de la colonne B_44_ANNONCES_ANTERIEURES

# %%
df_ = df.loc[:, ['B_44_ANNONCES_ANTERIEURES']].copy()

# %% [markdown]
# # Lecture des dernières lignes

# %%
df_.loc[df_.B_44_ANNONCES_ANTERIEURES.notna(),:].tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                B_44_ANNONCES_ANTERIEURES
# 745  [{"REFERENCE": {"IDWEB": "23-88639", "TYPE_AVIS": {"FAMILLE": {"FNS": ""}, "PERIMETRE": {"FNSimple": ""}, "NATURE": {"APPEL_OFFRE": {"STANDARD": ""}}, "STATUT": {"INITIAL": ""}}, "DATE_ENVOI": "2023-06-26"}, "REFERENCE_PUBLICATION": {"PUBLICATION_ELECTRONIQUE": {"DATE_PUBLICATION": "2023-06-27", "DATE_FIN_DIFFUSION": "2023-08-02"}}}, {"REFERENCE": {"IDWEB": "23-90646", "TYPE_AVIS": {"FAMILLE": {"FNS": ""}, "PERIMETRE": {"FNSimple": ""}, "NATURE": {"RECTIFICATIF": ""}, "STATUT": {"RECTIFICATI...
# 747                                     {"REFERENCE": {"IDWEB": "23-127777", "TYPE_AVIS": {"FAMILLE": {"JOUE": ""}, "PERIMETRE": {"DIRECTIVE-24": ""}, "NATURE": {"APPEL_OFFRE": {"STANDARD": ""}}, "STATUT": {"INITIAL": ""}}, "DATE_ENVOI": "2023-09-13"}, "REFERENCE_PUBLICATION": [{"PUBLICATION_ELECTRONIQUE": {"DATE_PUBLICATION": "2023-09-16", "DATE_FIN_DIFFUSION": "2023-10-10"}}, {"PUBLICATION_JOUE": {"ANNEE": "2023", "NUM_PARUTION": "179", "NUM_ANNONCE": "561578", "DATE_PUBLICATION": "2023-09-18"}}]}
# 749                                      {"REFERENCE": {"IDWEB": "23-69049", "TYPE_AVIS": {"FAMILLE": {"JOUE": ""}, "PERIMETRE": {"DIRECTIVE-24": ""}, "NATURE": {"APPEL_OFFRE": {"STANDARD": ""}}, "STATUT": {"INITIAL": ""}}, "DATE_ENVOI": "2023-05-22"}, "REFERENCE_PUBLICATION": [{"PUBLICATION_ELECTRONIQUE": {"DATE_PUBLICATION": "2023-05-25", "DATE_FIN_DIFFUSION": "2023-06-27"}}, {"PUBLICATION_JOUE": {"ANNEE": "2023", "NUM_PARUTION": "101", "NUM_ANNONCE": "319272", "DATE_PUBLICATION": "2023-05-26"}}]}
# 754                                                                                                                                                                       {"REFERENCE": {"IDWEB": "23-169290", "TYPE_AVIS": {"FAMILLE": {"FNS": ""}, "PERIMETRE": {"FNSimple": ""}, "NATURE": {"APPEL_OFFRE": {"STANDARD": ""}}, "STATUT": {"INITIAL": ""}}, "DATE_ENVOI": "2023-12-05"}, "REFERENCE_PUBLICATION": {"PUBLICATION_ELECTRONIQUE": {"DATE_PUBLICATION": "2023-12-06", "DATE_FIN_DIFFUSION": "2024-01-09"}}}
# 755                                      {"REFERENCE": {"IDWEB": "23-87648", "TYPE_AVIS": {"FAMILLE": {"JOUE": ""}, "PERIMETRE": {"DIRECTIVE-24": ""}, "NATURE": {"APPEL_OFFRE": {"STANDARD": ""}}, "STATUT": {"INITIAL": ""}}, "DATE_ENVOI": "2023-06-23"}, "REFERENCE_PUBLICATION": [{"PUBLICATION_ELECTRONIQUE": {"DATE_PUBLICATION": "2023-06-26", "DATE_FIN_DIFFUSION": "2023-07-25"}}, {"PUBLICATION_JOUE": {"ANNEE": "2023", "NUM_PARUTION": "122", "NUM_ANNONCE": "385195", "DATE_PUBLICATION": "2023-06-28"}}]}
