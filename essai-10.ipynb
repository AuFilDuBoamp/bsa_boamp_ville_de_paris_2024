# %%
import altair as alt
import pandas as pd

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity ='all'

# %%
df = pd.read_csv('/kaggle/input/datagouv-ville-paris-csv/df-bsa-paris-boamp-2024-initiale-integrale.csv', dtype='string')

# %%
#essai
df.B_09_dateParution.max()
df.head()
# Out:
# '2024-09-26'
#   B_01_annonceLie B_02_annonceReferenceSchemaV110  \
# 0            <NA>                            <NA>
# 1            <NA>                            <NA>
# 2            <NA>                            <NA>
# 3            <NA>                            <NA>
# 4            <NA>                            <NA>
#
#   B_03_annoncesAnterieuresSchemaV110 B_04_codeDepartement  \
# 0                               <NA>                   75
# 1                               <NA>                   75
# 2                               <NA>                   75
# 3                               <NA>                   75
# 4                               <NA>                   75
#
#   B_05_codeDepartementPrestation     B_06_criteres B_07_dateFinDiffusion  \
# 0                           <NA>              <NA>            2024-10-08
# 1                           <NA>              <NA>            2024-11-12
# 2                           <NA>              <NA>            2024-11-24
# ...
